# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghavendraReddy004/DV_Tasks_Repo/blob/main/DV_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("/content/IRIS - IRIS.csv")
print(data.columns)
plt.scatter(data['petal-length'], data['sepal-length'])
plt.xlabel('Petal Length (cm)')
plt.ylabel('Sepal Length (cm)')
plt.title('Petal Length vs Sepal Length')
plt.show()
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("/content/IRIS - IRIS.csv")
print(data.columns)
sns.barplot(x=data['petal-length'], y=data['petal-width'])
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Petal Length vs Petal Width')
plt.show()
import plotly.express as px
import pandas as pd

data = pd.read_csv("/content/IRIS - IRIS.csv")
df = pd.DataFrame(data)

species_counts = df[df.columns[-1]].value_counts().reset_index()
species_counts.columns = ['species', 'count']

fig = px.bar(species_counts, x='species', y='count')
fig.show()
import pandas as pd

df = pd.read_csv('/content/IRIS - IRIS.csv')

display(df.head())
display(df.info())
import pandas as pd

df = pd.read_csv("/content/IRIS - IRIS.csv")
display(df.head())
df.info()
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)

import pandas as pd

try:
    df = pd.read_csv("/content/IRIS - IRIS.csv")
    print("Dataset loaded successfully.")
except FileNotFoundError:
    print("Error: Iris (1).csv.xlsx not found. Please upload the dataset or provide the correct path.")
    exit()

print("\nMissing values before cleaning:")
print(df.isnull().sum())

initial_rows = df.shape[0]
df.drop_duplicates(inplace=True)
rows_after_dropping_duplicates = df.shape[0]

print(f"\nNumber of duplicate rows removed: {initial_rows - rows_after_dropping_duplicates}")

print("\nDataset after cleaning:")
display(df.head())
df.info()
# Out:
# Index(['sepal-length', 'sepal-width', 'petal-length', 'petal-width',
#        'species'],
#       dtype='object')
# Index(['sepal-length', 'sepal-width', 'petal-length', 'petal-width',
#        'species'],
#       dtype='object')
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
